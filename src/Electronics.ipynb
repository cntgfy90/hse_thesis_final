# %%
import re
import torch
import nltk
import numpy as np
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
from transformers import AdamW, BertTokenizer, BertModel, AutoModel, AutoTokenizer
from preprocess import preprocess
from skmultilearn.adapt import MLkNN, MLARAM
from skmultilearn.problem_transform import ClassifierChain
from sklearn.svm import SVC
lemmatizer = WordNetLemmatizer()
from sklearn.feature_extraction.text import TfidfVectorizer
from bert_base_cased import BertBaseCased
from bert_dataset import BertDataset
from bert_test import bert_test
from bert_train import bert_train
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, hamming_loss
from sklearn.ensemble import RandomForestRegressor

STOPWORDS = set(stopwords.words('english'))

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# [nltk_data] Downloading package stopwords to /home/stepan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/stepan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/stepan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
device
# Out:
# 'cuda'

# %%
df = pd.read_csv('./datasets/electronics_1/final_data.csv')
df = df.dropna()
df = df[df['Category'].str.startswith('Categories')]
df = df.rename(columns={ 'Description': 'description', 'Category': 'category' })
df
# Out:
#                                              description  \
# 0      KeePass Password Safe is a free, open source, ...
# 1      XAMPP is a very easy to install Apache Distrib...
# 2      Technical analysis library with indicators lik...
# 3      AppServ is an merging open source software ins...
# 4      LibreOffice is a free and powerful office suit...
# ...                                                  ...
# 33765  Find recursively corrupted or password protect...
# 33766  *** This repository has been migrated here: ht...
# 33767  Phoebetria lets you take control of your BitFe...
# 33768  - English (Thanks Steve for translation this t...
# 33769  Debugger for Bash version 3(Bourne again shell...
#
#                                                 category
# 0      Categories\nOffice/Business, Database, Securit...
# 1      Categories\nDatabase Engines/Servers, Dynamic ...
# 2      Categories\nInvestment Management, Spreadsheet...
# 3      Categories\nDatabase Engines/Servers, Site Man...
# 4      Categories\nWord Processors, Office Suites, Fr...
# ...                                                  ...
# 33765                          Categories\nFile Managers
# 33766                              Categories\nEmulators
# 33767             Categories\nHardware, Hardware Drivers
# 33768         Categories\nSoftware Distribution, Live CD
# 33769               Categories\nDebuggers, System Shells
#
# [33768 rows x 2 columns]

# %%
def prepare_category(x):
    result = x.split('\n')
    result.pop(0)
    return ''.join(result).split(', ')

df['category'] = df['category'].apply(prepare_category)

# %%
df['category_count'] = df['category'].str.len()

# %%
df = df[(df['category_count'] > 1) & (df['category_count'] < 7)]
df = df.reset_index()
df = df.drop(['index', 'category_count'], axis=1)
df
# Out:
#                                              description  \
# 0      KeePass Password Safe is a free, open source, ...
# 1      XAMPP is a very easy to install Apache Distrib...
# 2      Technical analysis library with indicators lik...
# 3      AppServ is an merging open source software ins...
# 4      LibreOffice is a free and powerful office suit...
# ...                                                  ...
# 23675  The eznixOS is a respin of Debian GNU/Linux, c...
# 23676  Denise is a cycle accurate and platform indepe...
# 23677  Phoebetria lets you take control of your BitFe...
# 23678  - English (Thanks Steve for translation this t...
# 23679  Debugger for Bash version 3(Bourne again shell...
#
#                                                 category
# 0      [Office/Business, Database, Security, Desktop ...
# 1      [Database Engines/Servers, Dynamic Content, Si...
# 2      [Investment Management, Spreadsheet, Front-End...
# 3      [Database Engines/Servers, Site Management, HT...
# 4           [Word Processors, Office Suites, Front-Ends]
# ...                                                  ...
# 23675                         [OS distribution, Live CD]
# 23676                   [Games/Entertainment, Emulators]
# 23677                       [Hardware, Hardware Drivers]
# 23678                   [Software Distribution, Live CD]
# 23679                         [Debuggers, System Shells]
#
# [23680 rows x 2 columns]

# %%
df['category'].str.len().value_counts()
# Out:
# category
# 3    10958
# 2     9156
# 4     2220
# 5      752
# 6      594
# Name: count, dtype: int64

# %%
categories = sorted(list(set([x for batch in df['category'].tolist() for x in batch])))

for category in categories:
    df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# Out:
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# ...
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)
# /tmp/ipykernel_7142/3304295865.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[category] = df['category'].apply(lambda x: 1 if category in x else 0)

# %%
X_train, X_test = train_test_split(df, shuffle=True, test_size=0.2)

X_train.shape, X_test.shape

X_train = X_train.reset_index()
X_test = X_test.reset_index()

X_train.shape, X_test.shape
# Out:
# ((18944, 502), (4736, 502))

# %%
tokenizer = AutoTokenizer.from_pretrained('bert-base-cased')

MAX_LEN = 512
BATCH_SIZE = 8
EPOCHS = 1
LEARNING_RATE = 2e-5
NUM_CLASSES = len(categories)

train_dataset = BertDataset(X_train, MAX_LEN, tokenizer, categories)
test_dataset = BertDataset(X_test, MAX_LEN, tokenizer, categories)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                          num_workers=4, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                         num_workers=4, shuffle=False, pin_memory=True)

# %%
bert_model = BertBaseCased(NUM_CLASSES)
# model.load_state_dict(torch.load('Luxury_apparel_BERT.bin', map_location=torch.device(device)))
bert_model = bert_model.to(device)

# %%
def loss_fn(outputs, targets):
    return torch.nn.BCEWithLogitsLoss()(outputs, targets)

optimizer = torch.optim.AdamW(params=bert_model.parameters(),
                  lr=LEARNING_RATE, weight_decay=1e-6)

# %%
for epoch in range(EPOCHS):
    bert_train(
        model=bert_model,
        train_loader=train_loader,
        optimizer=optimizer,
        loss_fn=loss_fn,
        epoch=epoch,
        device=device,
    )
# Out:
# Batch: 0
# Epoch: 0, Loss:  0.7233775854110718
# Batch: 1
# Batch: 2
# Batch: 3
# Batch: 4
# Batch: 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 for epoch in range(EPOCHS):
# ----> 2     bert_train(
#       3         model=bert_model,
#       4         train_loader=train_loader,
#       5         optimizer=optimizer,
#       6         loss_fn=loss_fn,
#       7         epoch=epoch,
#       8         device=device,
#       9     )
#
# File ~/HSEPythonCourse/thesis/hse_thesis_final/src/bert_train.py:7, in bert_train(model, train_loader, optimizer, loss_fn, epoch, device)
#       5 for _, data in enumerate(train_loader, 0):
#       6     print(f"Batch: {_}")
# ----> 7     ids = data['ids'].to(device)
#       8     mask = data['mask'].to(device)
#       9     token_type_ids = data['token_type_ids'].to(device)
#
# KeyboardInterrupt:
